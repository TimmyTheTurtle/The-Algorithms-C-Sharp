# %% [markdown]
# # 100-Level String Algorithms
#
# Interactive exploration of fundamental string manipulation algorithms.
#
# **Instructions:**
# - Read the algorithm description to understand WHAT it does and WHY
# - Each section has an empty code cell for you to implement
# - Write your implementation in the cell
# - Press `Shift+Enter` to run and test
# - Challenge yourself before looking at reference implementations

# %% [markdown]
# ## 1. String Reversal
#
# **What it is:**
# Take a string and output it backwards. Think of reading a word from right to left.
#
# **Why it matters for LLMs:**
# - Validating text normalization
# - Checking if output matches expected patterns
# - Preprocessing text for certain algorithms
#
# **Example:**
# - Input: `"hello"`
# - Output: `"olleh"`
#
# **Requirements:**
# - Handle empty strings
# - Handle single characters
# - Work with special characters and spaces

# %%
def reverse_string(s):
    """Reverse a string."""
    # Your code here
    return ""

# Test your implementation
print(reverse_string("hello"))   # Should display: olleh
print(reverse_string(""))        # Should display: (empty)
print(reverse_string("a"))       # Should display: a

# %% [markdown]
# ## 2. Palindrome Check
#
# **What it is:**
# Check if a string reads the same forwards and backwards. A palindrome is symmetric—it has mirror symmetry in text.
#
# **The algorithm:**
# 1. Clean the string (remove spaces, punctuation, make lowercase)
# 2. Compare the first character with the last
# 3. Compare the second with the second-to-last
# 4. Keep moving inward until you meet in the middle
# 5. If all match, it's a palindrome; if any don't, it's not
#
# **Why it matters for LLMs:**
# - Validating structured outputs (some formats require symmetry)
# - Finding patterns in generated text
# - Detecting malformed input
#
# **Examples:**
# - "racecar" → True (reads the same both ways)
# - "hello" → False (backwards is "olleh")
# - "A man, a plan, a canal: Panama" → True (if we clean it)
#
# **Requirements:**
# - Case-insensitive comparison
# - Handle spaces and punctuation
# - Return boolean (True/False)

# %%
def is_palindrome(s):
    """Check if a string is a palindrome."""
    # Your code here
    return False

# Test your implementation
print(is_palindrome("racecar"))      # Should display: True
print(is_palindrome("Racecar"))      # Should display: True (case-insensitive)
print(is_palindrome("race car"))     # Should display: True or False (depends on space handling)

# %% [markdown]
# ## 3. Count Characters
#
# **What it is:**
# Count how many times each character appears in a string. Return a dictionary/map of character → count.
#
# **How it works:**
# 1. Create an empty dictionary to store character counts
# 2. Loop through each character in the string
# 3. If character is already in dictionary, increment its count
# 4. If it's new, add it with count = 1
# 5. Return the dictionary
#
# **Example:**
# ```
# Input: "hello world"
# Output: {'h': 1, 'e': 1, 'l': 3, 'o': 2, ' ': 1, 'w': 1, 'r': 1, 'd': 1}
# ```
#
# **Why it matters for LLMs:**
# - Analyzing token frequency in generated text
# - Detecting patterns and repetition
# - Validating output diversity
#
# **Requirements:**
# - Return a dictionary with character counts
# - Handle empty strings
# - Include spaces and special characters

# %%
def count_characters(s):
    """Count frequency of each character in a string."""
    # Your code here
    return {}

# Test your implementation
counts = count_characters("hello world")
print(counts)  # Will display the character frequency dictionary

# %% [markdown]
# ## 4. Find Substring
#
# **What it is:**
# Find the index (position) where a substring first appears in a string. Return -1 if not found.
#
# **How it works (naive approach):**
# 1. Loop through the main string
# 2. At each position, check if the next N characters match the substring
# 3. If they match, return the current position
# 4. If we reach the end, return -1
#
# **Example:**
# ```
# String: "hello world"
# Find: "world"
# Result: 6 (position where "world" starts)
# ```
#
# **Why it matters for LLMs:**
# - Parsing structured outputs
# - Finding key phrases or patterns
# - Validating that expected content is present
#
# **Requirements:**
# - Return the index of first occurrence
# - Return -1 if not found
# - Handle edge cases (empty string, empty substring, etc.)

# %%
def find_substring(text, substring):
    """Find the index of the first occurrence of substring in text."""
    # Your code here
    return -1

# Test your implementation
print(find_substring("hello world", "world"))    # Expected: 6
print(find_substring("hello world", "xyz"))      # Expected: -1
print(find_substring("hello", "hello"))          # Expected: 0

# %% [markdown]
# ## 5. Anagrams
#
# **What it is:**
# Check if two strings are anagrams. Anagrams use exactly the same letters, just rearranged.
#
# **How it works:**
# 1. Clean both strings (remove spaces, make lowercase, ignore punctuation)
# 2. Count character frequencies in both strings
# 3. Compare the frequency counts
# 4. If they match, it's an anagram; if not, it's not
#
# **Example:**
# - "listen" and "silent" → True (same letters rearranged)
# - "hello" and "world" → False (different letters)
#
# **Why it matters for LLMs:**
# - Detecting text transformations
# - Validating consistency in generated content
# - Finding related phrases
#
# **Requirements:**
# - Case-insensitive
# - Ignore spaces and punctuation
# - Return boolean (True/False)

# %%
def are_anagrams(s1, s2):
    """Check if two strings are anagrams."""
    # Your code here
    return False

# Test your implementation
print(are_anagrams("listen", "silent"))         # Expected: True
print(are_anagrams("Listen", "Silent"))         # Expected: True
print(are_anagrams("hello", "world"))           # Expected: False

# %% [markdown]
# ## 6. Case Conversion
#
# **What it is:**
# Convert strings to uppercase or lowercase.
#
# **Why it matters for LLMs:**
# - Normalizing text before comparison
# - Formatting output consistently
# - Preprocessing for case-sensitive algorithms
#
# **Requirements:**
# - Implement convert_to_upper()
# - Implement convert_to_lower()
# - Handle special characters and numbers

# %%
def convert_to_upper(s):
    """Convert string to uppercase."""
    # Your code here
    return ""

def convert_to_lower(s):
    """Convert string to lowercase."""
    # Your code here
    return ""

# Test your implementation
print(convert_to_upper("Hello World"))   # Should display: HELLO WORLD
print(convert_to_lower("Hello World"))   # Should display: hello world

# %% [markdown]
# ## 7. Count Vowels and Consonants
#
# **What it is:**
# Count how many vowels and consonants are in a string.
#
# **Definitions:**
# - Vowels: A, E, I, O, U (and lowercase a, e, i, o, u)
# - Consonants: All other letters
# - Non-letters: Ignore spaces, numbers, punctuation
#
# **Why it matters for LLMs:**
# - Analyzing linguistic properties of generated text
# - Detecting language patterns
# - Validating output quality
#
# **Requirements:**
# - Return a tuple (vowel_count, consonant_count)
# - Case-insensitive
# - Ignore non-letter characters

# %%
def count_vowels_consonants(s):
    """Count vowels and consonants in a string."""
    # Your code here
    return (0, 0)

# Test your implementation
vowels, consonants = count_vowels_consonants("Hello World")
print(f"Vowels: {vowels}, Consonants: {consonants}")  # Display the result

# %% [markdown]
# ## 💡 Learning Tips
#
# ✓ Start with String Reversal—it's the simplest
# ✓ Use `print()` to see results—it works reliably in Python!
# ✓ Test edge cases: empty strings, single characters, special characters
# ✓ Python slicing `s[::-1]` is clean for reversal
# ✓ Once Phase 1 is done, move to Phase 2 (Search Algorithms)
#
# ---
#
# ## Challenge Problems
#
# Try these once you complete the 7 algorithms:
#
# 1. **Title Case** - "hello world" → "Hello World"
# 2. **Remove Duplicates** - "hello" → "helo"
# 3. **Longest Word** - "hello world python" → "python"
# 4. **Word Frequency** - Return dict of word counts
# 5. **Reverse Words Only** - "Hello World" → "World Hello"
